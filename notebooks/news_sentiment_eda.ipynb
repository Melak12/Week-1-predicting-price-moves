# %%
# load the autoreload extension for IPython
# This allows you to automatically reload modules before executing code
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

# Add the parent directory to the system path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scripts.sentiment_analysis import ArticleDataAnalyzer
# Out:
# ...
# NLTK resources downloaded.

# %%
# Load the data
raw_analyst_data = pd.read_csv('../data/raw_analyst_ratings.csv')

# Show all columns in the DataFrame
raw_analyst_data.columns= raw_analyst_data.columns.tolist()
# Display the columns
print("Columns in the DataFrame:")
for column in raw_analyst_data.columns:
    print(column)

# Show the first 5 rows of the DataFrame
raw_analyst_data.head(5)
# Out:
# ...
# NLTK resources downloaded.
# Columns in the DataFrame:
# Unnamed: 0
# headline
# url
# publisher
# date
# stock
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
# ...

# %%
analyzer = ArticleDataAnalyzer(raw_analyst_data)
analyzer.format_datetime()
# Out:
# NLTK resources not found. Downloading...
# NLTK resources downloaded.
# Date column formatted to datetime.

# %% [markdown]
# ## Publisher Analysis

# %%
analyzer.top_publishers_by_articles()
# Out:
# d:\active_repos\10_academy\Week-1-predicting-price-moves\scripts\sentiment_analysis.py:317: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_publishers.index, y=top_publishers.values, palette='viridis')

# %%
analyzer.common_words_by_top_publishers()
# Out:
# Most common words by top publishers:
#
# Allie Wickman:
# est: 5517
# vs: 5272
# reports: 3228
# eps: 3075
# revenues: 2624
# announces: 2221
# financial: 1400
# news: 1359
# summary: 1290
# morning: 1067
# breakfast: 1047
# update: 1041
# million: 1034
# new: 902
# us: 652
# energy: 648
# hearing: 625
# agreement: 612
# corporation: 537
# may: 526
#
# Benzinga Newsdesk:
# shares: 42666
# trading: 38834
# estimate: 29403
# stocks: 27841
# eps: 27419
# sales: 27375
# companies: 22019
# new: 21404
# several: 19667
# higher: 19010
# lower: 17682
# set: 16969
# yesterday: 13242
# price: 12029
# oil: 11329
# company: 11209
# us: 11099
# low: 10568
# benzinga: 9298
# coronavirus: 9119
#
# Benzinga Staff:
# reports: 4050
# announces: 3866
# eps: 3373
# quarter: 2212
# estimate: 1847
# results: 1718
# hits: 1488
# dividend: 1320
# update: 1309
# market: 1263
# corporation: 1249
# trading: 1183
# revenues: 1118
# markets: 1096
# equity: 1076
# high: 1045
# financial: 1020
# energy: 994
# ...

# %% [markdown]
# ## Article Analysis

# %%
analyzer.analyze_articles_by_weekday()
# Out:
# Articles published by weekday:
# weekday
# Monday       10297
# Tuesday      11037
# Wednesday    11873
# Thursday     12712
# Friday        9407
# Saturday       273
# Sunday         388
# Name: count, dtype: int64

# %%
analyzer.analyze_articles_by_month()
# Out:
# Articles published by month:
# month_name
# January       3072
# February      4092
# March         6392
# April         6466
# May          11364
# June          7966
# July          2133
# August        2857
# September     2419
# October       3079
# November      3209
# December      2938
# Name: count, dtype: int64

# %%
analyzer.extended_publication_frequency_analysis()

# %%
analyzer.identify_common_words_and_phrases()
# Out:
# Most common keywords:
# headline
# stocks        159102
# vs            138801
# eps           127403
# shares        112655
# reports       108429
# market         89225
# earnings       80855
# top            78354
# sales          77924
# pt             72733
# announces      66513
# price          63328
# downgrades     61862
# trading        60582
# raises         57735
# target         53530
# maintains      52958
# est            49316
# new            47662
# buy            43697
# Name: count, dtype: int64
# d:\active_repos\10_academy\Week-1-predicting-price-moves\scripts\sentiment_analysis.py:281: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=fdist.values, y=fdist.index, palette='Blues_d')
# Most common bigrams (phrases):
# price target : 46871
# stocks moving : 39966
# earnings scheduled : 32054
# ...

# %% [markdown]
# ### Sentiment Analysis

# %%
analyzer.sentiment_analysis()
# Out:
# Sentiment analysis complete. Columns 'sentiment_score' and 'sentiment_class' added.

# %%
analyzer.visualize_sentiment_score_by_top_publishers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 analyzer.visualize_sentiment_score_by_top_publishers()
#
# AttributeError: 'ArticleDataAnalyzer' object has no attribute 'visualize_sentiment_score_by_top_publishers'
